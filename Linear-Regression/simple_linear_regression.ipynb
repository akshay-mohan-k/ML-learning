# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/Placement2.csv', usecols=['CGPA', 'Salary (INR LPA)'])

# %%
df.head()
# Out:
#    CGPA  Salary (INR LPA)
# 0  7.90             17.63
# 1  7.39             28.37
# 2  8.02              8.95
# 3  8.72             22.59
# 4  7.31             19.67

# %%
df.sample(5)
# Out:
#      CGPA  Salary (INR LPA)
# 595  7.09              0.00
# 454  7.08             25.32
# 58   7.77             11.99
# 981  7.84             21.42
# 905  7.54              0.00

# %%
plt.scatter(x=df['CGPA'], y=df['Salary (INR LPA)'])
plt.xlabel('CGPA')
plt.ylabel('Salary (LPA)')
plt.show()

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_test.head()
# Out:
#      CGPA
# 37   5.93
# 726  7.51
# 846  7.73
# 295  6.95
# 924  8.46

# %%
y_test.head()
# Out:
# 37      4.35
# 726     0.00
# 846    26.03
# 295     0.00
# 924    17.61
# Name: Salary (INR LPA), dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# E:\ML-Learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([12.88799556])
