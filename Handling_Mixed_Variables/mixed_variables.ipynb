# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34',
#        'D19', 'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116',
#        'F', 'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22',
#        'B10', 'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64',
#        'A11', 'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89',
#        'F E46', 'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78',
#        'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60',
#        'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7',
#        'D40', 'D38', 'C105'], dtype=object)

# %%
df['Cabin_Num'] = df['Cabin'].str.extract('(\d+)') # captures numerical part
df['Cabin_Cat'] = df['Cabin'].str[0] # captures first letter

df.sample(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Akshay.Mohan\AppData\Local\Temp\ipykernel_16812\2427482363.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['Cabin_Num'] = df['Cabin'].str.extract('(\d+)') # captures numerical part
#      PassengerId  Survived  Pclass  \
# 51           943         0       2
# 333         1225         1       3
# 109         1001         0       2
# 187         1079         0       3
# 356         1248         1       1
# 53           945         1       1
# 163         1055         0       3
# 82           974         0       1
# 143         1035         0       2
# 238         1130         1       2
#
#                                                Name     Sex   Age  SibSp  \
# 51                               Pulbaum, Mr. Franz    male  27.0      0
# 333           Nakid, Mrs. Said (Waika Mary" Mowad)"  female  19.0      1
# 109                               Swane, Mr. George    male  18.5      0
# 187                              Davies, Mr. Joseph    male  17.0      2
# 356  Brown, Mrs. John Murray (Caroline Lane Lamson)  female  59.0      2
# 53                       Fortune, Miss. Ethel Flora  female  28.0      3
# 163                              Pearce, Mr. Ernest    male   NaN      0
# 82                           Case, Mr. Howard Brown    male  49.0      0
# 143                      Beauchamp, Mr. Henry James    male  28.0      0
# 238                           Hiltunen, Miss. Marta  female  18.0      1
#
#      Parch         Ticket      Fare        Cabin Embarked Cabin_Num Cabin_Cat
# 51       0  SC/PARIS 2168   15.0333          NaN        C       NaN       NaN
# 333      1           2653   15.7417          NaN        C       NaN       NaN
# 109      0         248734   13.0000            F        S       NaN         F
# 187      0      A/4 48873    8.0500          NaN        S       NaN       NaN
# 356      0          11769   51.4792         C101        S       101         C
# 53       2          19950  263.0000  C23 C25 C27        S        23         C
# 163      0         343271    7.0000          NaN        S       NaN       NaN
# 82       0          19924   26.0000          NaN        S       NaN       NaN
# 143      0         244358   26.0000          NaN        S       NaN       NaN
# 238      1         250650   13.0000          NaN        S       NaN       NaN
