# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/cars.csv', usecols=['brand','fuel', 'selling_price'])
df.head()
# Out:
#      brand    fuel  selling_price
# 0   Maruti  Diesel         450000
# 1    Skoda  Diesel         370000
# 2    Honda  Petrol         158000
# 3  Hyundai  Diesel         225000
# 4   Maruti  Petrol         130000

# %%
df.isnull().mean()*100
# Out:
# brand            0.147638
# fuel             0.159941
# selling_price    0.000000
# dtype: float64

# %%
df['brand'].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('brand')
plt.ylabel('fuel')
# Out:
# Text(0, 0.5, 'fuel')

# %%
df['brand'].mode()
# Out:
# 0    Maruti
# Name: brand, dtype: object
